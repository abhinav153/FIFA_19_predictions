# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import re


df = pd.read_csv('data.csv',usecols = ['Name','Preferred Foot','Weak Foot','Skill Moves','Work Rate','Height','Weight','Finishing','HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve','FKAccuracy','LongPassing','BallControl','Acceleration','SprintSpeed','Agility','Reactions','Balance','ShotPower','Jumping','Stamina','Strength','LongShots','Aggression','Interceptions','Positioning','Vision','Penalties','Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes','Overall','Potential','Position','Age','Release Clause'])

# %%
#dropping any rows with Nan values
df = df.dropna()


#Converting Height,Weight and Release Clause  which are stored in text format to numerical attributes
df['Weight'] = df['Weight'].apply(lambda x : int(x.split('lbs')[0]))

df['Height'] = df['Height'].apply(lambda x : float('.'.join(x.split("'"))))

def price_split(x):
    if x[-1] == 'M':
        return float(re.split('M',x[1:])[0])
    else:
        return float((re.split('K',x[1:])[0]))/1000

df['Release Clause'] = df['Release Clause'].apply(lambda x : price_split(x))

# %%
df.to_csv('clean_data.csv')

# %%
df
# Out:
#                        Name  Age  Overall  Potential Preferred Foot  \
# 0                  L. Messi   31       94         94           Left
# 1         Cristiano Ronaldo   33       94         94          Right
# 2                 Neymar Jr   26       92         93          Right
# 3                    De Gea   27       91         93          Right
# 4              K. De Bruyne   27       91         92          Right
# 5                 E. Hazard   27       91         91          Right
# 6                 L. Modrić   32       91         91          Right
# 7                 L. Suárez   31       91         91          Right
# 8              Sergio Ramos   32       91         91          Right
# 9                  J. Oblak   25       90         93          Right
# 10           R. Lewandowski   29       90         90          Right
# 11                 T. Kroos   28       90         90          Right
# 12                 D. Godín   32       90         90          Right
# ...
